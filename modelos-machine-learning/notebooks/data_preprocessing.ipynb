# %%
import pandas as pd

df = pd.read_csv('cleaned_global_video_game_sales.csv')
df

# %%
print(df.shape)
print(df.info())
print(df.head())

# %%
# Eliminar duplicados
df = df.drop_duplicates()

# %%
# Eliminar filas críticas nulas
df = df.dropna(subset=["Name", "Global_Sales"])

# %%
# Rellenar Publisher
df["Publisher"] = df["Publisher"].fillna("Unknown")
